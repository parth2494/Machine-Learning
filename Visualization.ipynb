# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fortune=pd.read_csv('fortune1000_final.csv', encoding='unicode_escape')

# %%
sns.distplot(fortune['Longitude'])

# %%
sns.distplot(fortune['Longitude'], kde=False, bins=10)

# %%
tips=sns.load_dataset('tips')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='scatter')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue='sex', palette='coolwarm')

# %%
iris=sns.load_dataset('iris')

# %%
g=sns.PairGrid('iris')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-4a8eaf193ae7> in <module>
# ----> 1 g=sns.PairGrid('iris')
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, corner, diag_sharey, height, aspect, layout_pad, despine, dropna, size)
#    1288                                  figsize=figsize,
#    1289                                  sharex="col", sharey="row",
# -> 1290                                  squeeze=False)
#    1291
#    1292         # Possibly remove upper axes to make a corner grid
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1175
#    1176     """
# -> 1177     fig = figure(**fig_kw)
#    1178     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1179                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     544                                         frameon=frameon,
#     545                                         FigureClass=FigureClass,
# --> 546                                         **kwargs)
#     547
#     548         if figLabel:
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3334         from matplotlib.figure import Figure
#    3335         fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3336         fig = fig_cls(*args, **kwargs)
#    3337         return cls.new_figure_manager_given_figure(num, fig)
#    3338
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\figure.py in __init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout)
#     347
#     348         if not np.isfinite(figsize).all() or (np.array(figsize) <= 0).any():
# --> 349             raise ValueError('figure size must be positive finite not '
#     350                              f'{figsize}')
#     351         self.bbox_inches = Bbox.from_bounds(0, 0, *figsize)
#
# ValueError: figure size must be positive finite not (0.0, 0.0)

# %%
g.map(plt.scatter)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-29d43b95b79e> in <module>
# ----> 1 g.map(plt.scatter)
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\axisgrid.py in map(self, func, **kwargs)
#    1355         row_indices, col_indices = np.indices(self.axes.shape)
#    1356         indices = zip(row_indices.flat, col_indices.flat)
# -> 1357         self._map_bivariate(func, indices, **kwargs)
#    1358         return self
#    1359
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\axisgrid.py in _map_bivariate(self, func, indices, **kwargs)
#    1496             y_var = self.y_vars[i]
#    1497             ax = self.axes[i, j]
# -> 1498             self._plot_bivariate(x_var, y_var, ax, func, kw_color, **kws)
#    1499         self._add_axis_labels()
#    1500
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\axisgrid.py in _plot_bivariate(self, x_var, y_var, ax, func, kw_color, **kwargs)
#    1501     def _plot_bivariate(self, x_var, y_var, ax, func, kw_color, **kwargs):
#    1502         """Draw a bivariate plot on the specified axes."""
# -> 1503         plt.sca(ax)
#    1504         if x_var == y_var:
#    1505             axes_vars = [x_var]
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in sca(ax)
#     856             m.canvas.figure.sca(ax)
#     857             return
# --> 858     raise ValueError("Axes instance argument was not found in a figure")
#     859
#     860
#
# ValueError: Axes instance argument was not found in a figure

# %%
g.map_diag(plt.hist)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-367a665900df> in <module>
# ----> 1 g.map_diag(plt.hist)
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\axisgrid.py in map_diag(self, func, **kwargs)
#    1461             hue_grouped = self.data[var].groupby(self.hue_vals)
#    1462
# -> 1463             plt.sca(ax)
#    1464
#    1465             for k, label_k in enumerate(self.hue_names):
#
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in sca(ax)
#     856             m.canvas.figure.sca(ax)
#     857             return
# --> 858     raise ValueError("Axes instance argument was not found in a figure")
#     859
#     860
#
# ValueError: Axes instance argument was not found in a figure

# %%
sns.pairplot(iris, hue='species', palette='rainbow')

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(), annot=True)

# %%
sns.heatmap(tips.corr(), annot=True)
plt.ylim(10,0)
# Out:
# (10.0, 0.0)

# %%
sns.heatmap(tips.corr(), annot=True)
plt.ylim(3,0)
# Out:
# (3.0, 0.0)

# %%
import seaborn as sns
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o','v'])

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='sex')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, row='sex', col='time')

# %%
sns.countplot(x='sex', data=tips)

# %%
sns.set_style('darkgrid')
sns.countplot(x='sex', data=tips)
