# %%
import pandas as pd

# %%
a = [11,1,1,2,3,4]

# %%
set(a)
# Out:
# {1, 2, 3, 4, 11}

# %%
pd.Series(a)
# Out:
# 0    11
# 1     1
# 2     1
# 3     2
# 4     3
# 5     4
# dtype: int64

# %%
type(a)
# Out:
# list

# %%
type(pd.Series(a))
# Out:
# pandas.core.series.Series

# %%
a = {'ABC':'Apple','XYZ':'Ball'}

# %%
a
# Out:
# {'ABC': 'Apple', 'XYZ': 'Ball'}

# %%
b = pd.Series(a)

# %%
b
# Out:
# ABC    Apple
# XYZ     Ball
# dtype: object

# %%
type(b)
# Out:
# pandas.core.series.Series

# %%
b['ABC']
# Out:
# 'Apple'

# %%
b.values
# Out:
# array(['Apple', 'Ball'], dtype=object)

# %%
b.index
# Out:
# Index(['ABC', 'XYZ'], dtype='object')

# %%
prices = [1,2,3,4.7585,6778.575868,5.6478]

# %%
s = pd.Series(prices)

# %%
s.sum()
# Out:
# 6794.982168

# %%
s.sum()
# Out:
# 6794.982168

# %%
s.product()
# Out:
# 1093047.648517928

# %%
s.mean()
# Out:
# 1132.497028

# %%
s.sum()/len(s)
# Out:
# 1132.497028

# %%
pokemon = pd.read_csv('pokemon.csv')

# %%
pokemon = pokemon['name']

# %%
type(pokemon)
# Out:
# pandas.core.series.Series

# %%
pokemon
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 796    Celesteela
# 797       Kartana
# 798      Guzzlord
# 799      Necrozma
# 800      Magearna
# Name: name, Length: 801, dtype: object

# %%
pokemon.head(50)
# Out:
# 0      Bulbasaur
# 1        Ivysaur
# 2       Venusaur
# 3     Charmander
# 4     Charmeleon
# 5      Charizard
# 6       Squirtle
# 7      Wartortle
# 8      Blastoise
# 9       Caterpie
# 10       Metapod
# 11    Butterfree
# 12        Weedle
# 13        Kakuna
# 14      Beedrill
# 15        Pidgey
# 16     Pidgeotto
# 17       Pidgeot
# 18       Rattata
# 19      Raticate
# 20       Spearow
# 21        Fearow
# 22         Ekans
# 23         Arbok
# 24       Pikachu
# 25        Raichu
# 26     Sandshrew
# 27     Sandslash
# 28      Nidoran♀
# 29      Nidorina
# 30     Nidoqueen
# 31      Nidoran♂
# 32      Nidorino
# 33      Nidoking
# 34      Clefairy
# 35      Clefable
# 36        Vulpix
# 37     Ninetales
# 38    Jigglypuff
# 39    Wigglytuff
# 40         Zubat
# 41        Golbat
# 42        Oddish
# 43         Gloom
# 44     Vileplume
# 45         Paras
# 46      Parasect
# 47       Venonat
# 48      Venomoth
# 49       Diglett
# Name: name, dtype: object

# %%
pokemon.head(10)
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# 5     Charizard
# 6      Squirtle
# 7     Wartortle
# 8     Blastoise
# 9      Caterpie
# Name: name, dtype: object

# %%
sorted(pokemon)
# Out:
# ['Abomasnow',
#  'Abra',
#  'Absol',
#  'Accelgor',
#  'Aegislash',
#  'Aerodactyl',
#  'Aggron',
#  'Aipom',
#  'Alakazam',
#  'Alomomola',
#  'Altaria',
#  'Amaura',
#  'Ambipom',
#  'Amoonguss',
#  'Ampharos',
#  'Anorith',
#  'Araquanid',
#  'Arbok',
#  'Arcanine',
#  'Arceus',
#  'Archen',
#  'Archeops',
#  'Ariados',
#  'Armaldo',
#  'Aromatisse',
#  'Aron',
#  'Articuno',
#  'Audino',
#  'Aurorus',
#  'Avalugg',
#  'Axew',
#  'Azelf',
#  'Azumarill',
#  'Azurill',
#  'Bagon',
#  'Baltoy',
#  'Banette',
#  'Barbaracle',
#  'Barboach',
#  'Basculin',
#  'Bastiodon',
#  'Bayleef',
#  'Beartic',
#  'Beautifly',
#  'Beedrill',
#  'Beheeyem',
#  'Beldum',
#  'Bellossom',
#  'Bellsprout',
#  'Bergmite',
#  'Bewear',
#  'Bibarel',
#  'Bidoof',
#  'Binacle',
#  'Bisharp',
#  'Blastoise',
#  'Blaziken',
#  'Blissey',
#  'Blitzle',
#  'Boldore',
#  'Bonsly',
#  'Bouffalant',
#  'Bounsweet',
#  'Braixen',
#  'Braviary',
#  'Breloom',
#  'Brionne',
#  'Bronzong',
#  'Bronzor',
# ...

# %%
prices = pd.Series(prices)

# %%
sorted(prices)
# Out:
# [1.0, 2.0, 3.0, 4.7585, 5.6478, 6778.575868]

# %%
max(pokemon)
# Out:
# 'Zygarde'

# %%
min(pokemon)
# Out:
# 'Abomasnow'

# %%
min(prices)
# Out:
# 1.0

# %%
pokemon.is_unique
# Out:
# True

# %%
pokemon.ndim
# Out:
# 1

# %%
pokemon
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 796    Celesteela
# 797       Kartana
# 798      Guzzlord
# 799      Necrozma
# 800      Magearna
# Name: name, Length: 801, dtype: object

# %%
prices
# Out:
# 0       1.000000
# 1       2.000000
# 2       3.000000
# 3       4.758500
# 4    6778.575868
# 5       5.647800
# dtype: float64

# %%
pokemon.shape
# Out:
# (801,)

# %%
pokemon.size
# Out:
# 801

# %%
prices.name

# %%
pokemon.name
# Out:
# 'name'

# %%
pokemon.sort_values(ascending=False)
# Out:
# 717      Zygarde
# 633     Zweilous
# 40         Zubat
# 569        Zorua
# 570      Zoroark
#          ...
# 680    Aegislash
# 616     Accelgor
# 358        Absol
# 62          Abra
# 459    Abomasnow
# Name: name, Length: 801, dtype: object

# %%
pokemon.sort_values()
# Out:
# 459    Abomasnow
# 62          Abra
# 358        Absol
# 616     Accelgor
# 680    Aegislash
#          ...
# 570      Zoroark
# 569        Zorua
# 40         Zubat
# 633     Zweilous
# 717      Zygarde
# Name: name, Length: 801, dtype: object

# %%
p = pokemon.copy()

# %%
p
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 796    Celesteela
# 797       Kartana
# 798      Guzzlord
# 799      Necrozma
# 800      Magearna
# Name: name, Length: 801, dtype: object

# %%
p.sort_values(inplace=True)

# %%
p
# Out:
# 459    Abomasnow
# 62          Abra
# 358        Absol
# 616     Accelgor
# 680    Aegislash
#          ...
# 570      Zoroark
# 569        Zorua
# 40         Zubat
# 633     Zweilous
# 717      Zygarde
# Name: name, Length: 801, dtype: object

# %%
30 in [1,2,3,4,5]
# Out:
# False

# %%
459 in p.values
# Out:
# False

# %%
459 in p.index
# Out:
# True

# %%
pokemon[0]
# Out:
# 'Bulbasaur'

# %%
p[0]
# Out:
# 'Bulbasaur'

# %%
p.reset_index()
# Out:
#      index       name
# 0      459  Abomasnow
# 1       62       Abra
# 2      358      Absol
# 3      616   Accelgor
# 4      680  Aegislash
# ..     ...        ...
# 796    570    Zoroark
# 797    569      Zorua
# 798     40      Zubat
# 799    633   Zweilous
# 800    717    Zygarde
#
# [801 rows x 2 columns]

# %%
pokemon[:10]
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# 5     Charizard
# 6      Squirtle
# 7     Wartortle
# 8     Blastoise
# 9      Caterpie
# Name: name, dtype: object

# %%
pokemon.tail()
# Out:
# 796    Celesteela
# 797       Kartana
# 798      Guzzlord
# 799      Necrozma
# 800      Magearna
# Name: name, dtype: object

# %%
pokemon[-5:]
# Out:
# 796    Celesteela
# 797       Kartana
# 798      Guzzlord
# 799      Necrozma
# 800      Magearna
# Name: name, dtype: object

# %%
pokemon = pd.read_csv("pokemon.csv", index_col='name',squeeze=True)

# %%
pokemon = pokemon['abilities']

# %%
pokemon
# Out:
# name
# Bulbasaur     ['Overgrow', 'Chlorophyll']
# Ivysaur       ['Overgrow', 'Chlorophyll']
# Venusaur      ['Overgrow', 'Chlorophyll']
# Charmander       ['Blaze', 'Solar Power']
# Charmeleon       ['Blaze', 'Solar Power']
#                          ...
# Celesteela                ['Beast Boost']
# Kartana                   ['Beast Boost']
# Guzzlord                  ['Beast Boost']
# Necrozma                  ['Prism Armor']
# Magearna                   ['Soul-Heart']
# Name: abilities, Length: 801, dtype: object

# %%
pokemon[0]
# Out:
# "['Overgrow', 'Chlorophyll']"

# %%
pokemon['Bulbasaur']
# Out:
# "['Overgrow', 'Chlorophyll']"

# %%
pokemon = pd.read_csv("pokemon.csv", index_col='name',squeeze=True)

# %%
pokemon.head()
# Out:
#                               abilities  against_bug  against_dark  \
# name
# Bulbasaur   ['Overgrow', 'Chlorophyll']          1.0           1.0
# Ivysaur     ['Overgrow', 'Chlorophyll']          1.0           1.0
# Venusaur    ['Overgrow', 'Chlorophyll']          1.0           1.0
# Charmander     ['Blaze', 'Solar Power']          0.5           1.0
# Charmeleon     ['Blaze', 'Solar Power']          0.5           1.0
#
#             against_dragon  against_electric  against_fairy  against_fight  \
# name
# Bulbasaur              1.0               0.5            0.5            0.5
# Ivysaur                1.0               0.5            0.5            0.5
# Venusaur               1.0               0.5            0.5            0.5
# Charmander             1.0               1.0            0.5            1.0
# Charmeleon             1.0               1.0            0.5            1.0
#
#             against_fire  against_flying  against_ghost  ...  percentage_male  \
# ...

# %%
pokemon.axes
# Out:
# [Index(['Bulbasaur', 'Ivysaur', 'Venusaur', 'Charmander', 'Charmeleon',
#         'Charizard', 'Squirtle', 'Wartortle', 'Blastoise', 'Caterpie',
#         ...
#         'Lunala', 'Nihilego', 'Buzzwole', 'Pheromosa', 'Xurkitree',
#         'Celesteela', 'Kartana', 'Guzzlord', 'Necrozma', 'Magearna'],
#        dtype='object', name='name', length=801),
#  Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#         'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#         'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#         'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#         'against_rock', 'against_steel', 'against_water', 'attack',
#         'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#         'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#         'japanese_name', 'percentage_male', 'pokedex_number', 'sp_attack',
# ...

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 801 entries, Bulbasaur to Magearna
# Data columns (total 40 columns):
# abilities            801 non-null object
# against_bug          801 non-null float64
# against_dark         801 non-null float64
# against_dragon       801 non-null float64
# against_electric     801 non-null float64
# against_fairy        801 non-null float64
# against_fight        801 non-null float64
# against_fire         801 non-null float64
# against_flying       801 non-null float64
# against_ghost        801 non-null float64
# against_grass        801 non-null float64
# against_ground       801 non-null float64
# against_ice          801 non-null float64
# against_normal       801 non-null float64
# against_poison       801 non-null float64
# against_psychic      801 non-null float64
# against_rock         801 non-null float64
# against_steel        801 non-null float64
# against_water        801 non-null float64
# attack               801 non-null int64
# ...

# %%
pokemon[['attack','speed']]
# Out:
#             attack  speed
# name
# Bulbasaur       49     45
# Ivysaur         62     60
# Venusaur       100     80
# Charmander      52     65
# Charmeleon      64     80
# ...            ...    ...
# Celesteela     101     61
# Kartana        181    109
# Guzzlord       101     43
# Necrozma       107     79
# Magearna        95     65
#
# [801 rows x 2 columns]

# %%
pokemon['abc'] = 1

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 801 entries, Bulbasaur to Magearna
# Data columns (total 41 columns):
# abilities            801 non-null object
# against_bug          801 non-null float64
# against_dark         801 non-null float64
# against_dragon       801 non-null float64
# against_electric     801 non-null float64
# against_fairy        801 non-null float64
# against_fight        801 non-null float64
# against_fire         801 non-null float64
# against_flying       801 non-null float64
# against_ghost        801 non-null float64
# against_grass        801 non-null float64
# against_ground       801 non-null float64
# against_ice          801 non-null float64
# against_normal       801 non-null float64
# against_poison       801 non-null float64
# against_psychic      801 non-null float64
# against_rock         801 non-null float64
# against_steel        801 non-null float64
# against_water        801 non-null float64
# attack               801 non-null int64
# ...

# %% [markdown]
# # DATAFRAMES

# %%
pokemon = pd.read_csv("pokemon.csv",index_col='name')

# %%
pokemon.head()
# Out:
#                               abilities  against_bug  against_dark  \
# name
# Bulbasaur   ['Overgrow', 'Chlorophyll']          1.0           1.0
# Ivysaur     ['Overgrow', 'Chlorophyll']          1.0           1.0
# Venusaur    ['Overgrow', 'Chlorophyll']          1.0           1.0
# Charmander     ['Blaze', 'Solar Power']          0.5           1.0
# Charmeleon     ['Blaze', 'Solar Power']          0.5           1.0
#
#             against_dragon  against_electric  against_fairy  against_fight  \
# name
# Bulbasaur              1.0               0.5            0.5            0.5
# Ivysaur                1.0               0.5            0.5            0.5
# Venusaur               1.0               0.5            0.5            0.5
# Charmander             1.0               1.0            0.5            1.0
# Charmeleon             1.0               1.0            0.5            1.0
#
#             against_fire  against_flying  against_ghost  ...  percentage_male  \
# ...

# %%
pokemon['attack'].sum()
# Out:
# 62364

# %%
pokemon['type1'].value_counts()
# Out:
# water       114
# normal      105
# grass        78
# bug          72
# psychic      53
# fire         52
# rock         45
# electric     39
# poison       32
# ground       32
# dark         29
# fighting     28
# dragon       27
# ghost        27
# steel        24
# ice          23
# fairy        18
# flying        3
# Name: type1, dtype: int64

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 801 entries, Bulbasaur to Magearna
# Data columns (total 40 columns):
# abilities            801 non-null object
# against_bug          801 non-null float64
# against_dark         801 non-null float64
# against_dragon       801 non-null float64
# against_electric     801 non-null float64
# against_fairy        801 non-null float64
# against_fight        801 non-null float64
# against_fire         801 non-null float64
# against_flying       801 non-null float64
# against_ghost        801 non-null float64
# against_grass        801 non-null float64
# against_ground       801 non-null float64
# against_ice          801 non-null float64
# against_normal       801 non-null float64
# against_poison       801 non-null float64
# against_psychic      801 non-null float64
# against_rock         801 non-null float64
# against_steel        801 non-null float64
# against_water        801 non-null float64
# attack               801 non-null int64
# ...

# %%
del pokemon['type2']

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 801 entries, Bulbasaur to Magearna
# Data columns (total 39 columns):
# abilities            801 non-null object
# against_bug          801 non-null float64
# against_dark         801 non-null float64
# against_dragon       801 non-null float64
# against_electric     801 non-null float64
# against_fairy        801 non-null float64
# against_fight        801 non-null float64
# against_fire         801 non-null float64
# against_flying       801 non-null float64
# against_ghost        801 non-null float64
# against_grass        801 non-null float64
# against_ground       801 non-null float64
# against_ice          801 non-null float64
# against_normal       801 non-null float64
# against_poison       801 non-null float64
# against_psychic      801 non-null float64
# against_rock         801 non-null float64
# against_steel        801 non-null float64
# against_water        801 non-null float64
# attack               801 non-null int64
# ...

# %%
pokemon.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'percentage_male', 'pokedex_number', 'sp_attack',
#        'sp_defense', 'speed', 'type1', 'weight_kg', 'generation',
#        'is_legendary'],
#       dtype='object')

# %%
pokemon.drop(['abilities', 'against_bug', 'against_dark', 'against_dragon'],axis=1,inplace=True)

# %%
pokemon.drop(['Necrozma','Magearna'],inplace=True)

# %%
pokemon.head()
# Out:
#             against_electric  against_fairy  against_fight  against_fire  \
# name
# Bulbasaur                0.5            0.5            0.5           2.0
# Ivysaur                  0.5            0.5            0.5           2.0
# Venusaur                 0.5            0.5            0.5           2.0
# Charmander               1.0            0.5            1.0           0.5
# Charmeleon               1.0            0.5            1.0           0.5
#
#             against_flying  against_ghost  against_grass  against_ground  \
# name
# Bulbasaur              2.0            1.0           0.25             1.0
# Ivysaur                2.0            1.0           0.25             1.0
# Venusaur               2.0            1.0           0.25             1.0
# Charmander             1.0            1.0           0.50             2.0
# Charmeleon             1.0            1.0           0.50             2.0
#
#             against_ice  against_normal  ...     japanese_name  \
# ...

# %%
pokemon.head()
# Out:
#             against_electric  against_fairy  against_fight  against_fire  \
# name
# Bulbasaur                0.5            0.5            0.5           2.0
# Ivysaur                  0.5            0.5            0.5           2.0
# Venusaur                 0.5            0.5            0.5           2.0
# Charmander               1.0            0.5            1.0           0.5
# Charmeleon               1.0            0.5            1.0           0.5
#
#             against_flying  against_ghost  against_grass  against_ground  \
# name
# Bulbasaur              2.0            1.0           0.25             1.0
# Ivysaur                2.0            1.0           0.25             1.0
# Venusaur               2.0            1.0           0.25             1.0
# Charmander             1.0            1.0           0.50             2.0
# Charmeleon             1.0            1.0           0.50             2.0
#
#             against_ice  against_normal  ...     japanese_name  \
# ...

# %%
pokemon
# Out:
#             against_electric  against_fairy  against_fight  against_fire  \
# name
# Bulbasaur                0.5            0.5            0.5           2.0
# Ivysaur                  0.5            0.5            0.5           2.0
# Venusaur                 0.5            0.5            0.5           2.0
# Charmander               1.0            0.5            1.0           0.5
# Charmeleon               1.0            0.5            1.0           0.5
# ...                      ...            ...            ...           ...
# Pheromosa                1.0            2.0            0.5           2.0
# Xurkitree                0.5            1.0            1.0           1.0
# Celesteela               2.0            0.5            1.0           2.0
# Kartana                  0.5            0.5            2.0           4.0
# Guzzlord                 0.5            4.0            2.0           0.5
#
#             against_flying  against_ghost  against_grass  against_ground  \
# name
# ...

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 799 entries, Bulbasaur to Guzzlord
# Data columns (total 35 columns):
# against_electric     799 non-null float64
# against_fairy        799 non-null float64
# against_fight        799 non-null float64
# against_fire         799 non-null float64
# against_flying       799 non-null float64
# against_ghost        799 non-null float64
# against_grass        799 non-null float64
# against_ground       799 non-null float64
# against_ice          799 non-null float64
# against_normal       799 non-null float64
# against_poison       799 non-null float64
# against_psychic      799 non-null float64
# against_rock         799 non-null float64
# against_steel        799 non-null float64
# against_water        799 non-null float64
# attack               799 non-null int64
# base_egg_steps       799 non-null int64
# base_happiness       799 non-null int64
# base_total           799 non-null int64
# capture_rate         799 non-null object
# ...

# %%
pokemon.dropna(inplace=True)

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 684 entries, Bulbasaur to Kommo-o
# Data columns (total 35 columns):
# against_electric     684 non-null float64
# against_fairy        684 non-null float64
# against_fight        684 non-null float64
# against_fire         684 non-null float64
# against_flying       684 non-null float64
# against_ghost        684 non-null float64
# against_grass        684 non-null float64
# against_ground       684 non-null float64
# against_ice          684 non-null float64
# against_normal       684 non-null float64
# against_poison       684 non-null float64
# against_psychic      684 non-null float64
# against_rock         684 non-null float64
# against_steel        684 non-null float64
# against_water        684 non-null float64
# attack               684 non-null int64
# base_egg_steps       684 non-null int64
# base_happiness       684 non-null int64
# base_total           684 non-null int64
# capture_rate         684 non-null object
# ...

# %%
pokemon
# Out:
#             against_electric  against_fairy  against_fight  against_fire  \
# name
# Bulbasaur                0.5            0.5            0.5           2.0
# Ivysaur                  0.5            0.5            0.5           2.0
# Venusaur                 0.5            0.5            0.5           2.0
# Charmander               1.0            0.5            1.0           0.5
# Charmeleon               1.0            0.5            1.0           0.5
# ...                      ...            ...            ...           ...
# Bruxish                  2.0            1.0            0.5           0.5
# Drampa                   0.5            2.0            2.0           0.5
# Jangmo-o                 0.5            2.0            1.0           0.5
# Hakamo-o                 0.5            4.0            1.0           0.5
# Kommo-o                  0.5            4.0            1.0           0.5
#
#             against_flying  against_ghost  against_grass  against_ground  \
# name
# ...

# %%
a = (pokemon['type1'] == 'grass')

# %%
pokemon[a]
# Out:
#            against_electric  against_fairy  against_fight  against_fire  \
# name
# Bulbasaur               0.5            0.5            0.5           2.0
# Ivysaur                 0.5            0.5            0.5           2.0
# Venusaur                0.5            0.5            0.5           2.0
# Oddish                  0.5            0.5            0.5           2.0
# Gloom                   0.5            0.5            0.5           2.0
# ...                     ...            ...            ...           ...
# Morelull                0.5            1.0            0.5           2.0
# Shiinotic               0.5            1.0            0.5           2.0
# Bounsweet               0.5            1.0            1.0           2.0
# Steenee                 0.5            1.0            1.0           2.0
# Tsareena                0.5            1.0            1.0           2.0
#
#            against_flying  against_ghost  against_grass  against_ground  \
# name
# ...

# %%
pokemon[(pokemon['type1'] == 'grass')]
# Out:
#            against_electric  against_fairy  against_fight  against_fire  \
# name
# Bulbasaur               0.5            0.5            0.5           2.0
# Ivysaur                 0.5            0.5            0.5           2.0
# Venusaur                0.5            0.5            0.5           2.0
# Oddish                  0.5            0.5            0.5           2.0
# Gloom                   0.5            0.5            0.5           2.0
# ...                     ...            ...            ...           ...
# Morelull                0.5            1.0            0.5           2.0
# Shiinotic               0.5            1.0            0.5           2.0
# Bounsweet               0.5            1.0            1.0           2.0
# Steenee                 0.5            1.0            1.0           2.0
# Tsareena                0.5            1.0            1.0           2.0
#
#            against_flying  against_ghost  against_grass  against_ground  \
# name
# ...

# %%
pokemon[(pokemon['against_electric'] > 0.5) & (pokemon['against_fight'] == 2.0)]
# Out:
#               against_electric  against_fairy  against_fight  against_fire  \
# name
# Dewgong                    2.0            1.0            2.0           1.0
# Cloyster                   2.0            1.0            2.0           1.0
# Lickitung                  1.0            1.0            2.0           1.0
# Chansey                    1.0            1.0            2.0           1.0
# Kangaskhan                 1.0            1.0            2.0           1.0
# ...                        ...            ...            ...           ...
# Crabominable               1.0            2.0            2.0           2.0
# Rockruff                   1.0            1.0            2.0           0.5
# Stufful                    1.0            2.0            2.0           1.0
# Bewear                     1.0            2.0            2.0           1.0
# Komala                     1.0            1.0            2.0           1.0
#
# ...

# %%
pokemon[(pokemon['against_electric'] > 0.5) | (pokemon['against_fight'] == 2.0)]
# Out:
#             against_electric  against_fairy  against_fight  against_fire  \
# name
# Charmander               1.0            0.5            1.0           0.5
# Charmeleon               1.0            0.5            1.0           0.5
# Charizard                2.0            0.5            0.5           0.5
# Squirtle                 2.0            1.0            1.0           0.5
# Wartortle                2.0            1.0            1.0           0.5
# ...                      ...            ...            ...           ...
# Komala                   1.0            1.0            2.0           1.0
# Togedemaru               0.5            0.5            2.0           2.0
# Mimikyu                  1.0            1.0            0.0           1.0
# Bruxish                  2.0            1.0            0.5           0.5
# Drampa                   0.5            2.0            2.0           0.5
#
#             against_flying  against_ghost  against_grass  against_ground  \
# name
# ...

# %%
pokemon[pokemon['type1'].isin(['grass', 'water', 'fire'])]
# Out:
#             against_electric  against_fairy  against_fight  against_fire  \
# name
# Bulbasaur                0.5            0.5            0.5          2.00
# Ivysaur                  0.5            0.5            0.5          2.00
# Venusaur                 0.5            0.5            0.5          2.00
# Charmander               1.0            0.5            1.0          0.50
# Charmeleon               1.0            0.5            1.0          0.50
# ...                      ...            ...            ...           ...
# Steenee                  0.5            1.0            1.0          2.00
# Tsareena                 0.5            1.0            1.0          2.00
# Pyukumuku                2.0            1.0            1.0          0.50
# Turtonator               0.5            1.0            1.0          0.25
# Bruxish                  2.0            1.0            0.5          0.50
#
#             against_flying  against_ghost  against_grass  against_ground  \
# name
# ...

# %%
pokemon[pokemon.duplicated()]
# Out:
# Empty DataFrame
# Columns: [against_electric, against_fairy, against_fight, against_fire, against_flying, against_ghost, against_grass, against_ground, against_ice, against_normal, against_poison, against_psychic, against_rock, against_steel, against_water, attack, base_egg_steps, base_happiness, base_total, capture_rate, classfication, defense, experience_growth, height_m, hp, japanese_name, percentage_male, pokedex_number, sp_attack, sp_defense, speed, type1, weight_kg, generation, is_legendary]
# Index: []
#
# [0 rows x 35 columns]

# %%
pokemon['against_electric'].unique()
# Out:
# array([0.5, 1. , 2. , 0. , 4. ])

# %%
pokemon['against_electric'].nunique()
# Out:
# 5
