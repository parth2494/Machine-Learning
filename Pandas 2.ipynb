# %%
import pandas as pd

# %%
pokemon = pd.read_csv("pokemon.csv")

# %%
pokemon.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
pokemon[pokemon['sp_attack'].between(80,100)]
# Out:
#                                       abilities  against_bug  against_dark  \
# 1                   ['Overgrow', 'Chlorophyll']          1.0           1.0
# 4                      ['Blaze', 'Solar Power']          0.5           1.0
# 11              ['Compoundeyes', 'Tinted Lens']          0.5           1.0
# 25   ['Static', 'Lightningrod', 'Surge Surfer']          1.0           1.0
# 33   ['Poison Point', 'Rivalry', 'Sheer Force']          0.5           1.0
# ..                                          ...          ...           ...
# 783   ['Bulletproof', 'Soundproof', 'Overcoat']          0.5           0.5
# 784             ['Electric Surge', 'Telepathy']          0.5           0.5
# 786               ['Grassy Surge', 'Telepathy']          1.0           0.5
# 787                ['Misty Surge', 'Telepathy']          0.5           0.5
# 798                             ['Beast Boost']          2.0           0.5
#
# ...

# %%
pokemon.head(10)
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3     ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4     ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 5     ['Blaze', 'Solar Power']         0.25           1.0             1.0
# 6     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 7     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 8     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 9  ['Shield Dust', 'Run Away']         1.00           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# ...

# %%
pokemon.set_index(keys='name', inplace=True)

# %%
pokemon.head()
# Out:
#                               abilities  against_bug  against_dark  \
# name
# Bulbasaur   ['Overgrow', 'Chlorophyll']          1.0           1.0
# Ivysaur     ['Overgrow', 'Chlorophyll']          1.0           1.0
# Venusaur    ['Overgrow', 'Chlorophyll']          1.0           1.0
# Charmander     ['Blaze', 'Solar Power']          0.5           1.0
# Charmeleon     ['Blaze', 'Solar Power']          0.5           1.0
#
#             against_dragon  against_electric  against_fairy  against_fight  \
# name
# Bulbasaur              1.0               0.5            0.5            0.5
# Ivysaur                1.0               0.5            0.5            0.5
# Venusaur               1.0               0.5            0.5            0.5
# Charmander             1.0               1.0            0.5            1.0
# Charmeleon             1.0               1.0            0.5            1.0
#
#             against_fire  against_flying  against_ghost  ...  percentage_male  \
# ...

# %%
pokemon.reset_index(inplace=True)

# %%
pokemon.head()
# Out:
#          name                    abilities  against_bug  against_dark  \
# 0   Bulbasaur  ['Overgrow', 'Chlorophyll']          1.0           1.0
# 1     Ivysaur  ['Overgrow', 'Chlorophyll']          1.0           1.0
# 2    Venusaur  ['Overgrow', 'Chlorophyll']          1.0           1.0
# 3  Charmander     ['Blaze', 'Solar Power']          0.5           1.0
# 4  Charmeleon     ['Blaze', 'Solar Power']          0.5           1.0
#
#    against_dragon  against_electric  against_fairy  against_fight  \
# 0             1.0               0.5            0.5            0.5
# 1             1.0               0.5            0.5            0.5
# 2             1.0               0.5            0.5            0.5
# 3             1.0               1.0            0.5            1.0
# 4             1.0               1.0            0.5            1.0
#
#    against_fire  against_flying  ...  percentage_male  pokedex_number  \
# 0           2.0             2.0  ...             88.1               1
# ...

# %%
pokemon.set_index(keys='name', inplace=True)

# %%
pokemon.loc['Pikachu']
# Out:
# abilities            ['Static', 'Lightningrod']
# against_bug                                   1
# against_dark                                  1
# against_dragon                                1
# against_electric                            0.5
# against_fairy                                 1
# against_fight                                 1
# against_fire                                  1
# against_flying                              0.5
# against_ghost                                 1
# against_grass                                 1
# against_ground                                2
# against_ice                                   1
# against_normal                                1
# against_poison                                1
# against_psychic                               1
# against_rock                                  1
# against_steel                               0.5
# against_water                                 1
# attack                                       55
# ...

# %%
pokemon['Bulbasaur': 'Pikachu']
# Out:
#                                                     abilities  against_bug  \
# name
# Bulbasaur                         ['Overgrow', 'Chlorophyll']         1.00
# Ivysaur                           ['Overgrow', 'Chlorophyll']         1.00
# Venusaur                          ['Overgrow', 'Chlorophyll']         1.00
# Charmander                           ['Blaze', 'Solar Power']         0.50
# Charmeleon                           ['Blaze', 'Solar Power']         0.50
# Charizard                            ['Blaze', 'Solar Power']         0.25
# Squirtle                             ['Torrent', 'Rain Dish']         1.00
# Wartortle                            ['Torrent', 'Rain Dish']         1.00
# Blastoise                            ['Torrent', 'Rain Dish']         1.00
# Caterpie                          ['Shield Dust', 'Run Away']         1.00
# Metapod                                         ['Shed Skin']         1.00
# ...

# %%
pokemon.loc['Bulbasaur': 'Pikachu']
# Out:
#                                                     abilities  against_bug  \
# name
# Bulbasaur                         ['Overgrow', 'Chlorophyll']         1.00
# Ivysaur                           ['Overgrow', 'Chlorophyll']         1.00
# Venusaur                          ['Overgrow', 'Chlorophyll']         1.00
# Charmander                           ['Blaze', 'Solar Power']         0.50
# Charmeleon                           ['Blaze', 'Solar Power']         0.50
# Charizard                            ['Blaze', 'Solar Power']         0.25
# Squirtle                             ['Torrent', 'Rain Dish']         1.00
# Wartortle                            ['Torrent', 'Rain Dish']         1.00
# Blastoise                            ['Torrent', 'Rain Dish']         1.00
# Caterpie                          ['Shield Dust', 'Run Away']         1.00
# Metapod                                         ['Shed Skin']         1.00
# ...

# %%
pokemon.iloc[0]
# Out:
# abilities            ['Overgrow', 'Chlorophyll']
# against_bug                                    1
# against_dark                                   1
# against_dragon                                 1
# against_electric                             0.5
# against_fairy                                0.5
# against_fight                                0.5
# against_fire                                   2
# against_flying                                 2
# against_ghost                                  1
# against_grass                               0.25
# against_ground                                 1
# against_ice                                    2
# against_normal                                 1
# against_poison                                 1
# against_psychic                                2
# against_rock                                   1
# against_steel                                  1
# against_water                                0.5
# ...

# %%
pokemon.iloc[0:5]
# Out:
#                               abilities  against_bug  against_dark  \
# name
# Bulbasaur   ['Overgrow', 'Chlorophyll']          1.0           1.0
# Ivysaur     ['Overgrow', 'Chlorophyll']          1.0           1.0
# Venusaur    ['Overgrow', 'Chlorophyll']          1.0           1.0
# Charmander     ['Blaze', 'Solar Power']          0.5           1.0
# Charmeleon     ['Blaze', 'Solar Power']          0.5           1.0
#
#             against_dragon  against_electric  against_fairy  against_fight  \
# name
# Bulbasaur              1.0               0.5            0.5            0.5
# Ivysaur                1.0               0.5            0.5            0.5
# Venusaur               1.0               0.5            0.5            0.5
# Charmander             1.0               1.0            0.5            1.0
# Charmeleon             1.0               1.0            0.5            1.0
#
#             against_fire  against_flying  against_ghost  ...  percentage_male  \
# ...

# %%
pokemon.ix['Bulbasaur']
# Out:
# d:\anaconda3\envs\deeplearning tf modulekeras\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# abilities            ['Overgrow', 'Chlorophyll']
# against_bug                                    1
# against_dark                                   1
# against_dragon                                 1
# against_electric                             0.5
# against_fairy                                0.5
# against_fight                                0.5
# against_fire                                   2
# against_flying                                 2
# against_ghost                                  1
# against_grass                               0.25
# against_ground                                 1
# ...

# %%
pokemon.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'percentage_male', 'pokedex_number', 'sp_attack',
#        'sp_defense', 'speed', 'type1', 'type2', 'weight_kg', 'generation',
#        'is_legendary'],
#       dtype='object')

# %%
pokemon.rename(columns={'against_bug':'bug'}, inplace=True)

# %%
pokemon.head()
# Out:
#                               abilities  bug  against_dark  against_dragon  \
# name
# Bulbasaur   ['Overgrow', 'Chlorophyll']  1.0           1.0             1.0
# Ivysaur     ['Overgrow', 'Chlorophyll']  1.0           1.0             1.0
# Venusaur    ['Overgrow', 'Chlorophyll']  1.0           1.0             1.0
# Charmander     ['Blaze', 'Solar Power']  0.5           1.0             1.0
# Charmeleon     ['Blaze', 'Solar Power']  0.5           1.0             1.0
#
#             against_electric  against_fairy  against_fight  against_fire  \
# name
# Bulbasaur                0.5            0.5            0.5           2.0
# Ivysaur                  0.5            0.5            0.5           2.0
# Venusaur                 0.5            0.5            0.5           2.0
# Charmander               1.0            0.5            1.0           0.5
# Charmeleon               1.0            0.5            1.0           0.5
#
# ...

# %%
pokemon.columns = ['abilities', 'bug', 'dark', 'dragon',
       'electric', 'fairy', 'fight', 'fire',
       'flying', 'ghost', 'grass', 'ground',
       'ice', 'normal', 'poison', 'psychic',
       'rock', 'steel', 'water', 'attack',
       'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
       'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
       'japanese_name', 'percentage_male', 'pokedex_number', 'sp_attack',
       'sp_defense', 'speed', 'type1', 'type2', 'weight_kg', 'generation',
       'is_legendary']

# %%
pokemon.head()
# Out:
#                               abilities  bug  dark  dragon  electric  fairy  \
# name
# Bulbasaur   ['Overgrow', 'Chlorophyll']  1.0   1.0     1.0       0.5    0.5
# Ivysaur     ['Overgrow', 'Chlorophyll']  1.0   1.0     1.0       0.5    0.5
# Venusaur    ['Overgrow', 'Chlorophyll']  1.0   1.0     1.0       0.5    0.5
# Charmander     ['Blaze', 'Solar Power']  0.5   1.0     1.0       1.0    0.5
# Charmeleon     ['Blaze', 'Solar Power']  0.5   1.0     1.0       1.0    0.5
#
#             fight  fire  flying  ghost  ...  percentage_male  pokedex_number  \
# name                                    ...
# Bulbasaur     0.5   2.0     2.0    1.0  ...             88.1               1
# Ivysaur       0.5   2.0     2.0    1.0  ...             88.1               2
# Venusaur      0.5   2.0     2.0    1.0  ...             88.1               3
# Charmander    1.0   0.5     1.0    1.0  ...             88.1               4
# ...

# %%
pokemon.sample(n=3, random_state= 99)
# Out:
#                                          abilities  bug  dark  dragon  \
# name
# Chimecho                              ['Levitate']  2.0   2.0     1.0
# Dewott                  ['Torrent', 'Shell Armor']  1.0   1.0     1.0
# Beheeyem  ['Telepathy', 'Synchronize', 'Analytic']  2.0   2.0     1.0
#
#           electric  fairy  fight  fire  flying  ghost  ...  percentage_male  \
# name                                                   ...
# Chimecho       1.0    1.0    0.5   1.0     1.0    2.0  ...             50.0
# Dewott         2.0    1.0    1.0   0.5     1.0    1.0  ...             88.1
# Beheeyem       1.0    1.0    0.5   1.0     1.0    2.0  ...             50.0
#
#           pokedex_number  sp_attack  sp_defense  speed    type1  type2  \
# name
# Chimecho             358         95          90     65  psychic    NaN
# Dewott               502         83          60     60    water    NaN
# Beheeyem             606        125          95     40  psychic    NaN
#
# ...

# %%
pokemon.sample(frac=0.2, random_state=10)
# Out:
#                                                    abilities  bug  dark  \
# name
# Sandslash  ['Sand Veil', 'Sand Rush', 'Snow Cloak', 'Slus...  1.0   1.0
# Zangoose                         ['Immunity', 'Toxic Boost']  1.0   1.0
# Keldeo                                         ['Justified']  0.5   0.5
# Piplup                                ['Torrent', 'Defiant']  1.0   1.0
# Servine                             ['Overgrow', 'Contrary']  2.0   1.0
# ...                                                      ...  ...   ...
# Archen                                         ['Defeatist']  0.5   1.0
# Vivillon     ['Shield Dust', 'Compoundeyes', 'Friend Guard']  0.5   1.0
# Totodile                          ['Torrent', 'Sheer Force']  1.0   1.0
# Bagon                           ['Rock Head', 'Sheer Force']  1.0   1.0
# Zygarde                    ['Aura Break', 'Power Construct']  1.0   1.0
#
#            dragon  electric  fairy  fight  fire  flying  ghost  ...  \
# ...

# %%
pokemon.where(pokemon['sp_attack']> 100).dropna()
# Out:
#                                                  abilities   bug  dark  \
# name
# Venusaur                       ['Overgrow', 'Chlorophyll']  1.00   1.0
# Charizard                         ['Blaze', 'Solar Power']  0.25   1.0
# Pidgeot          ['Keen Eye', 'Tangled Feet', 'Big Pecks']  0.50   1.0
# Vileplume                  ['Chlorophyll', 'Effect Spore']  1.00   1.0
# Slowbro          ['Oblivious', 'Own Tempo', 'Regenerator']  2.00   2.0
# Haunter                                       ['Levitate']  0.25   2.0
# Gengar                                     ['Cursed Body']  0.25   2.0
# Jynx                 ['Oblivious', 'Forewarn', 'Dry Skin']  2.00   2.0
# Omastar        ['Swift Swim', 'Shell Armor', 'Weak Armor']  1.00   1.0
# Houndoom           ['Early Bird', 'Flash Fire', 'Unnerve']  1.00   0.5
# Blaziken                          ['Blaze', 'Speed Boost']  0.25   0.5
# Gardevoir            ['Synchronize', 'Trace', 'Telepathy']  1.00   1.0
# ...

# %%
pokemon[pokemon['sp_attack']> 100]
# Out:
#                                             abilities   bug  dark  dragon  \
# name
# Venusaur                  ['Overgrow', 'Chlorophyll']  1.00   1.0     1.0
# Charizard                    ['Blaze', 'Solar Power']  0.25   1.0     1.0
# Blastoise                    ['Torrent', 'Rain Dish']  1.00   1.0     1.0
# Pidgeot     ['Keen Eye', 'Tangled Feet', 'Big Pecks']  0.50   1.0     1.0
# Vileplume             ['Chlorophyll', 'Effect Spore']  1.00   1.0     1.0
# ...                                               ...   ...   ...     ...
# Pheromosa                             ['Beast Boost']  0.50   0.5     1.0
# Xurkitree                             ['Beast Boost']  1.00   1.0     1.0
# Celesteela                            ['Beast Boost']  0.25   1.0     0.5
# Necrozma                              ['Prism Armor']  2.00   2.0     1.0
# Magearna                               ['Soul-Heart']  0.25   0.5     0.0
#
# ...

# %%
pokemon['sp_attack'].dropna()
# Out:
# name
# Bulbasaur      65
# Ivysaur        80
# Venusaur      122
# Charmander     60
# Charmeleon     80
#              ...
# Celesteela    107
# Kartana        59
# Guzzlord       97
# Necrozma      127
# Magearna      130
# Name: sp_attack, Length: 801, dtype: int64

# %%
pokemon.head()
# Out:
#                               abilities  bug  dark  dragon  electric  fairy  \
# name
# Bulbasaur   ['Overgrow', 'Chlorophyll']  1.0   1.0     1.0       0.5    0.5
# Ivysaur     ['Overgrow', 'Chlorophyll']  1.0   1.0     1.0       0.5    0.5
# Venusaur    ['Overgrow', 'Chlorophyll']  1.0   1.0     1.0       0.5    0.5
# Charmander     ['Blaze', 'Solar Power']  0.5   1.0     1.0       1.0    0.5
# Charmeleon     ['Blaze', 'Solar Power']  0.5   1.0     1.0       1.0    0.5
#
#             fight  fire  flying  ghost  ...  percentage_male  pokedex_number  \
# name                                    ...
# Bulbasaur     0.5   2.0     2.0    1.0  ...             88.1               1
# Ivysaur       0.5   2.0     2.0    1.0  ...             88.1               2
# Venusaur      0.5   2.0     2.0    1.0  ...             88.1               3
# Charmander    1.0   0.5     1.0    1.0  ...             88.1               4
# ...

# %%
pokemon = pd.read_csv("pokemon.csv")

# %%
pokemon_new = pokemon.copy()

# %%
pokemon_new.set_index("name", inplace=True)

# %%
pokemon_new.head()
# Out:
#                               abilities  against_bug  against_dark  \
# name
# Bulbasaur   ['Overgrow', 'Chlorophyll']          1.0           1.0
# Ivysaur     ['Overgrow', 'Chlorophyll']          1.0           1.0
# Venusaur    ['Overgrow', 'Chlorophyll']          1.0           1.0
# Charmander     ['Blaze', 'Solar Power']          0.5           1.0
# Charmeleon     ['Blaze', 'Solar Power']          0.5           1.0
#
#             against_dragon  against_electric  against_fairy  against_fight  \
# name
# Bulbasaur              1.0               0.5            0.5            0.5
# Ivysaur                1.0               0.5            0.5            0.5
# Venusaur               1.0               0.5            0.5            0.5
# Charmander             1.0               1.0            0.5            1.0
# Charmeleon             1.0               1.0            0.5            1.0
#
#             against_fire  against_flying  against_ghost  ...  percentage_male  \
# ...

# %%
pokemon.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
pokemon_new = pokemon.copy()

# %%
pokemon_new.set_index(['japanese_name', 'name'], inplace=True)

# %%
pokemon_new.head()
# Out:
#                                                abilities  against_bug  \
# japanese_name    name
# Fushigidaneフシギダネ Bulbasaur   ['Overgrow', 'Chlorophyll']          1.0
# Fushigisouフシギソウ  Ivysaur     ['Overgrow', 'Chlorophyll']          1.0
# Fushigibanaフシギバナ Venusaur    ['Overgrow', 'Chlorophyll']          1.0
# Hitokageヒトカゲ     Charmander     ['Blaze', 'Solar Power']          0.5
# Lizardoリザード      Charmeleon     ['Blaze', 'Solar Power']          0.5
#
#                              against_dark  against_dragon  against_electric  \
# japanese_name    name
# Fushigidaneフシギダネ Bulbasaur            1.0             1.0               0.5
# Fushigisouフシギソウ  Ivysaur              1.0             1.0               0.5
# Fushigibanaフシギバナ Venusaur             1.0             1.0               0.5
# Hitokageヒトカゲ     Charmander           1.0             1.0               1.0
# Lizardoリザード      Charmeleon           1.0             1.0               1.0
#
# ...

# %%
pokemon_new.index.set_names(['Jap Name', 'Name'], inplace=True)

# %%
pokemon_new.head()
# Out:
#                                                abilities  against_bug  \
# Jap Name         Name
# Fushigidaneフシギダネ Bulbasaur   ['Overgrow', 'Chlorophyll']          1.0
# Fushigisouフシギソウ  Ivysaur     ['Overgrow', 'Chlorophyll']          1.0
# Fushigibanaフシギバナ Venusaur    ['Overgrow', 'Chlorophyll']          1.0
# Hitokageヒトカゲ     Charmander     ['Blaze', 'Solar Power']          0.5
# Lizardoリザード      Charmeleon     ['Blaze', 'Solar Power']          0.5
#
#                              against_dark  against_dragon  against_electric  \
# Jap Name         Name
# Fushigidaneフシギダネ Bulbasaur            1.0             1.0               0.5
# Fushigisouフシギソウ  Ivysaur              1.0             1.0               0.5
# Fushigibanaフシギバナ Venusaur             1.0             1.0               0.5
# Hitokageヒトカゲ     Charmander           1.0             1.0               1.0
# Lizardoリザード      Charmeleon           1.0             1.0               1.0
#
# ...

# %%
pokemon_new.sort_index(ascending=[False])
# Out:
#                                                                         abilities  \
# Jap Name                Name
# Zygarde (10% Forme)ジガルデ Zygarde                 ['Aura Break', 'Power Construct']
# Zuruzukinズルズキン          Scrafty              ['Shed Skin', 'Moxie', 'Intimidate']
# Zurugguズルッグ             Scraggy              ['Shed Skin', 'Moxie', 'Intimidate']
# Zugaidosズガイドス           Cranidos                  ['Mold Breaker', 'Sheer Force']
# Zubatズバット               Zubat                      ['Inner Focus', 'Infiltrator']
# ...                                                                           ...
# Achamoアチャモ              Torchic                          ['Blaze', 'Speed Boost']
# Aburibbonアブリボン          Ribombee    ['Honey Gather', 'Shield Dust', 'Sweet Veil']
# Abulyアブリー               Cutiefly    ['Honey Gather', 'Shield Dust', 'Sweet Veil']
# Absolアブソル               Absol             ['Pressure', 'Super Luck', 'Justified']
# ...
